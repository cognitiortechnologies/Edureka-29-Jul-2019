# %%
def revenue():
    new_rev = 150*100
    print(new_rev)

# %%
revenue()
# Out:
# 15000

# %%
def revenue(to_cust):
    new_rev = to_cust*100
    print(new_rev)

# %%
revenue(104)
# Out:
# 10400

# %%
def revenue(to_cust, to_price):
    new_rev = to_cust*to_price
    print(new_rev)

# %%
revenue(10,10)
# Out:
# 100

# %%
def revenue(to_cust=200, to_price=150):
    new_rev = to_cust*to_price
    print(new_rev)

# %%
revenue(to_price=125)
# Out:
# 25000

# %%
def financials(revenue, expense):
    """This function will help us to find the profit and profitratio"""
    profit = revenue-expense
    profitratio = profit/revenue
    #new_financials = (profit, profitratio)
    new_financials = [profit, profitratio]
    #print(profit)
    #print(profitratio)
    #print(new_financials)
    return new_financials
    #return profit
    #return profitratio

# %%
new_amount = financials(1000,10)

# %%
new_amount
# Out:
# [990, 0.99]

# %%
profitratio=10

# %%
profitratio
# Out:
# 10

# %%
raw_data = {'cust_id': [1,2,3,4,5,6],
           'First Name': ['A','B','C','D','E','F'],
           'Last Name': ['X','Y','Z','P','Q','R']}

# %%
raw_data
# Out:
# {'cust_id': [1, 2, 3, 4, 5, 6],
#  'First Name': ['A', 'B', 'C', 'D', 'E', 'F'],
#  'Last Name': ['X', 'Y', 'Z', 'P', 'Q', 'R']}

# %%
import pandas as pd

# %%
customer_detail = pd.DataFrame(raw_data)

# %%
customer_detail
# Out:
#    cust_id First Name Last Name
# 0        1          A         X
# 1        2          B         Y
# 2        3          C         Z
# 3        4          D         P
# 4        5          E         Q
# 5        6          F         R

# %%
raw_data1 = {'cid': [1,2,3,4,7],
            'sales':[123,234,443,445,444],
            'product': ['Python','Tableau','PowerBI','R','Python']}

# %%
raw_data1
# Out:
# {'cid': [1, 2, 3, 4, 7],
#  'sales': [123, 234, 443, 445, 444],
#  'product': ['Python', 'Tableau', 'PowerBI', 'R', 'Python']}

# %%
sales_details = pd.DataFrame(raw_data1)

# %%
sales_details
# Out:
#    cid  sales  product
# 0    1    123   Python
# 1    2    234  Tableau
# 2    3    443  PowerBI
# 3    4    445        R
# 4    7    444   Python

# %%
customer_detail
# Out:
#    cust_id First Name Last Name
# 0        1          A         X
# 1        2          B         Y
# 2        3          C         Z
# 3        4          D         P
# 4        5          E         Q
# 5        6          F         R

# %%
pd.merge(customer_detail,sales_details, left_on='cust_id', right_on='cid', how='inner')
# Out:
#    cust_id First Name Last Name  cid  sales  product
# 0        1          A         X    1    123   Python
# 1        2          B         Y    2    234  Tableau
# 2        3          C         Z    3    443  PowerBI
# 3        4          D         P    4    445        R

# %%
pd.merge(customer_detail,sales_details, left_on='cust_id', right_on='cid', how='left')
# Out:
#    cust_id First Name Last Name  cid  sales  product
# 0        1          A         X  1.0  123.0   Python
# 1        2          B         Y  2.0  234.0  Tableau
# 2        3          C         Z  3.0  443.0  PowerBI
# 3        4          D         P  4.0  445.0        R
# 4        5          E         Q  NaN    NaN      NaN
# 5        6          F         R  NaN    NaN      NaN

# %%
pd.merge(customer_detail,sales_details, left_on='cust_id', right_on='cid', how='right')
# Out:
#    cust_id First Name Last Name  cid  sales  product
# 0      1.0          A         X    1    123   Python
# 1      2.0          B         Y    2    234  Tableau
# 2      3.0          C         Z    3    443  PowerBI
# 3      4.0          D         P    4    445        R
# 4      NaN        NaN       NaN    7    444   Python

# %%
pd.merge(customer_detail,sales_details, left_on='cust_id', right_on='cid', how='outer')
# Out:
#    cust_id First Name Last Name  cid  sales  product
# 0      1.0          A         X  1.0  123.0   Python
# 1      2.0          B         Y  2.0  234.0  Tableau
# 2      3.0          C         Z  3.0  443.0  PowerBI
# 3      4.0          D         P  4.0  445.0        R
# 4      5.0          E         Q  NaN    NaN      NaN
# 5      6.0          F         R  NaN    NaN      NaN
# 6      NaN        NaN       NaN  7.0  444.0   Python

# %%
pd.concat([customer_detail,sales_details],axis=1)
# Out:
#    cust_id First Name Last Name  cid  sales  product
# 0        1          A         X  1.0  123.0   Python
# 1        2          B         Y  2.0  234.0  Tableau
# 2        3          C         Z  3.0  443.0  PowerBI
# 3        4          D         P  4.0  445.0        R
# 4        5          E         Q  7.0  444.0   Python
# 5        6          F         R  NaN    NaN      NaN

# %%
tips1=pd.read_csv('tips.csv')

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\Edureka\\Edureka - 13th July - Python\\Class 3'

# %%
os.chdir('D:\\Edureka\\Edureka - 13th July - Python\\Class 3\\')

# %%
tips.tail(7)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
select total_bill, tip, smoker, time
from tips
limit 5

# %%
tips[['total_bill']].head(5)
# Out:
#    total_bill
# 0       16.99
# 1       10.34
# 2       21.01
# 3       23.68
# 4       24.59

# %%
select * from tips where time='Dinner' and tip>5

# %%
tips[(tips['time']=='Dinner') & (tips['tip']>5)]
# Out:
#      total_bill    tip     sex smoker  day    time  size
# 23        39.42   7.58    Male     No  Sat  Dinner     4
# 44        30.40   5.60    Male     No  Sun  Dinner     4
# 47        32.40   6.00    Male     No  Sun  Dinner     4
# 52        34.81   5.20  Female     No  Sun  Dinner     4
# 59        48.27   6.73    Male     No  Sat  Dinner     4
# 116       29.93   5.07    Male     No  Sun  Dinner     4
# 155       29.85   5.14  Female     No  Sun  Dinner     5
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3
# 172        7.25   5.15    Male    Yes  Sun  Dinner     2
# 181       23.33   5.65    Male    Yes  Sun  Dinner     2
# 183       23.17   6.50    Male    Yes  Sun  Dinner     4
# 211       25.89   5.16    Male    Yes  Sat  Dinner     4
# 212       48.33   9.00    Male     No  Sat  Dinner     4
# 214       28.17   6.50  Female    Yes  Sat  Dinner     3
# 239       29.03   5.92    Male     No  Sat  Dinner     3

# %%
select * from tips where size>=5 or total_bill>45

# %%
tips[(tips['smoker']=='No') & ((tips['size']>=5) | (tips['total_bill']>45))]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 59        48.27  6.73    Male     No   Sat  Dinner     4
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 142       41.19  5.00    Male     No  Thur   Lunch     5
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 212       48.33  9.00    Male     No   Sat  Dinner     4

# %%
select sex, count(*)
from tips
group by sex

# %%
tips.groupby('sex').size()
# Out:
# sex
# Female     87
# Male      157
# dtype: int64

# %%
#Having

# %%
import numpy as np

# %%
tips.groupby(['smoker','day']).agg({'tip':[np.size, np.mean]})
# Out:
#               tip
#              size      mean
# smoker day
# No     Fri    4.0  2.812500
#        Sat   45.0  3.102889
#        Sun   57.0  3.167895
#        Thur  45.0  2.673778
# Yes    Fri   15.0  2.714000
#        Sat   42.0  2.875476
#        Sun   19.0  3.516842
#        Thur  17.0  3.030000

# %%
stats = pd.read_csv('DemographicData.csv')

# %%
len(stats)
# Out:
# 195

# %%
len(stats.columns)
# Out:
# 5

# %%
stats.head(10)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244         78.9000
# 1           Afghanistan          AFG      35.253          5.9000
# 2                Angola          AGO      45.985         19.1000
# 3               Albania          ALB      12.877         57.2000
# 4  United Arab Emirates          ARE      11.044         88.0000
# 5             Argentina          ARG      17.716         59.9000
# 6               Armenia          ARM      13.308         41.9000
# 7   Antigua and Barbuda          ATG      16.447         63.4000
# 8             Australia          AUS      13.200         83.0000
# 9               Austria          AUT       9.400         80.6188
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# ...

# %%
stats.tail(10)
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 185  Virgin Islands (U.S.)          VIR      10.700            45.3
# 186                Vietnam          VNM      15.537            43.9
# 187                Vanuatu          VUT      26.739            11.3
# 188     West Bank and Gaza          PSE      30.394            46.6
# 189                  Samoa          WSM      26.172            15.3
# 190            Yemen, Rep.          YEM      32.947            20.0
# 191           South Africa          ZAF      20.850            46.5
# 192       Congo, Dem. Rep.          COD      42.394             2.2
# 193                 Zambia          ZMB      40.471            15.4
# 194               Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# ...

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.columns = ['CountryName','CountryCode','BirthRate', 'Internetusers','IncomeGroup']

# %%
stats = stats.rename(columns={'BR':'BirthRate'})

# %%
stats[12:15]
# Out:
#      CountryName CountryCode  BirthRate  Internetusers  IncomeGroup
# 12       Belgium         BEL     11.200        82.1702  High income
# 13         Benin         BEN     36.440         4.9000   Low income
# 14  Burkina Faso         BFA     40.551         9.1000   Low income

# %%
stats['Mycalc'] = stats.BirthRate  * stats.Internetusers

# %%
stats
# Out:
#                         CountryName CountryCode  BirthRate  Internetusers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# ...

# %%
stats = stats.drop('Mycalc', 1)

# %%
stats
# Out:
#                         CountryName CountryCode  BirthRate  Internetusers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# ...

# %%
stats[stats.Internetusers<2]
# Out:
#       CountryName CountryCode  BirthRate  Internetusers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lmplot(data=stats, x='Internetusers', y='BirthRate', fit_reg=False, hue='IncomeGroup')
